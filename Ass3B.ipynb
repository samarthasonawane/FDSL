# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("Housing.csv")

# %%
mean_val = df["price"].mean()
median_val = df["price"].median()
mode_val = df["price"].mode()[0]
print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)
# Out:
# --- Central Tendency of House Price ---
# Mean: 4766729.247706422
# Median: 4340000.0
# Mode: 3500000
