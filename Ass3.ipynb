# %%
import pandas as pd

# %%
df = pd.read_csv("Housing.csv")

# %%
total = 0
for price in prices:
    total = total + price

mean = total / len(prices)

print("\nMean =", mean)
# Out:
# Mean = 4766729.247706422

# %%
prices_sorted = sorted(prices)

n = len(prices_sorted)

if n % 2 == 1:
    median = prices_sorted[n // 2]
else:
    middle1 = prices_sorted[(n // 2) - 1]
    middle2 = prices_sorted[n // 2]
    median = (middle1 + middle2) / 2

print("Median =", median)
# Out:
# Median = 4340000

# %%
frequency = {}

for price in prices:

    if price in frequency:
        frequency[price] = frequency[price] + 1
    else:
        frequency[price] = 1

max_frequency = max(frequency.values())

modes = []

for price in frequency:

    if frequency[price] == max_frequency:
        modes.append(price)

print("Mode =", modes)
# Out:
# Mode = [4200000, 3500000]

# %%
if mean > median:
    print("Distribution is right (positively) skewed")

elif mean < median:
    print("Distribution is left (negatively) skewed")

else:
    print("Distribution is approximately symmetric")
# Out:
# Distribution is right (positively) skewed
